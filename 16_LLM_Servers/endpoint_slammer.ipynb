# %% [markdown]
# Now that you've deployed your endpoint - it's time to slam it!

# %%
import os
import getpass
from dotenv import load_dotenv

load_dotenv()

if not os.environ.get("FIREWORKS_API_KEY"):
    os.environ["FIREWORKS_API_KEY"] = getpass.getpass("Enter your Fireworks API key: ")

# %% [markdown]
# Let's try with 1 request, just to verify our endpoint is alive.
#
# Make sure you provide your own endpoint identifier! It will look something like this:
#
# - `accounts/fireworks/models/gpt-oss-20b` (serverless)
# - Or your custom on-demand deployment identifier

# %%
from langchain_fireworks import ChatFireworks

# REPLACE WITH YOUR OWN ENDPOINT IDENTIFIER
model_endpoint = "accounts/fireworks/models/gpt-oss-20b"

llm = ChatFireworks(model=model_endpoint)

response = llm.invoke("How much wood could a wood chuck chuck if a wood chuck could chuck wood?")
print(response.content)
# Out:
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x70b22f7ff320>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x70b22f7ffec0>
# Ah, the classic tongue‑twister that has baffled linguists, comedians, and wood‑crafters alike for centuries. The truth, as they say, is… not surprisingly, that woodchucks don’t actually chuck wood. But let’s indulge the question anyway, because the myth has spawned some surprisingly serious “research” from the world’s most eccentric scientists!
#
# ---
#
# ## The (non‑existent) Woodchuck
#
# - **Real life:** Woodchucks, or *Marmota monax* (the groundhog), are burrowing rodents known for their impressive tunnel systems. They chew on vegetation, but they never actually move a log from one side of a forest to the other.
# - **The myth:** The popular rhyme goes:
#   *“How much wood would a wood‑chuck chuck
#   If a wood‑chuck could chuck wood?”*
#   It’s a great rhythmic exercise, but it’s basically a tongue‑twister.
#
# ---
#
# ## A “Scientific” Estimate (for Fun)
#
# In 1997, a semi‑serious “wood‑chuck” study by the *Journal of Arboriculture* (fictional, of course) compared the volume of soil a woodchuck can excavate in a single burrow and extrapolated it to “wood” because both involve moving a bulk mass. The calculation went like this:
#
# 1. **Average trench volume excavated per year:** ≈ 40 cubic feet
# 2. **Bulking density of soil vs log wood:** 140 lb/ft³ (soil) ≈ 30 lb/ft³ (typical straight‑grade pine)
# 3. **Weight of wood per ft³ of data:** As a rough estimate, a 1‑inch diameter log has about 1 ft³ per 2.5 ft of length → ≈ 12 ft of wood per ft³ of volume.
#
# This leads to a **theoretical chucking capacity** of around **600–700 pounds of wood per year**—or, if a woodchuck got a morning coffee, about **1–2 pounds per day**.
#
# *Disclaimer:* That’s purely fictional. The authors later admitted that wooden logs were too heavy for the woodchuck's molars and that the study was conducted entirely in a cardboard box.
#
# ---
#
# ## Bottom Line
#
# - **Literal answer:** Woodchucks don’t chuck any actual wood.
# - **Tongue‑twister answer:** “A woodchuck would chuck as much wood as a woodchuck could chuck, if a woodchuck could chuck wood!”
#   Which, by the way, is the official answer from *The Oxford Dictionary of Funny Definitions*.
#
# Feel free to use this nugget of silliness in your next pun‑filled conversation or to impress friends at the trivia night. Either way, you’ve earned yourself a round of applause—real or imagined—for wrestling with the great mystery of the wood‑chuck!

# %% [markdown]
# Now, let's SLAM IT.

# %%
import asyncio

async def send_request(llm, idx):
    try:
        response = await llm.ainvoke(
            f"How much wood could a wood chuck chuck if a wood chuck could chuck wood? (Request {idx})"
        )
        print(f"Response {idx}: {response.content[:60]}...")
    except Exception as e:
        print(f"Request {idx} failed: {e}")

async def main():
    tasks = [send_request(llm, i) for i in range(1, 25)]
    await asyncio.gather(*tasks)

await main()
# Out:
# Request 14 failed: {"error":{"message":"You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.","param":null,"code":"RATE_LIMIT_EXCEEDED","type":"error"},"request_id":"chatcmpl-681f209bcb1c4936ac717493f12ce8d4"}
# Request 3 failed: {"error":{"message":"You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.","param":null,"code":"RATE_LIMIT_EXCEEDED","type":"error"},"request_id":"chatcmpl-ad7bcd9139ed4702827e33919da60851"}
# Request 22 failed: {"error":{"message":"You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.","param":null,"code":"RATE_LIMIT_EXCEEDED","type":"error"},"request_id":"chatcmpl-838cb39021504dfd92a7c2d53a8e26a4"}
# Request 19 failed: {"error":{"message":"You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.","param":null,"code":"RATE_LIMIT_EXCEEDED","type":"error"},"request_id":"chatcmpl-9b76dbc30fc7478a9743d62dbf37fe06"}
# Request 15 failed: {"error":{"message":"You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.","param":null,"code":"RATE_LIMIT_EXCEEDED","type":"error"},"request_id":"chatcmpl-5ef8fa5b4b444bb791cb30a15845bf81"}
# Request 8 failed: {"error":{"message":"You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.","param":null,"code":"RATE_LIMIT_EXCEEDED","type":"error"},"request_id":"chatcmpl-c008bbfcde62421abd76d2592104b3e5"}
# Request 6 failed: {"error":{"message":"You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.","param":null,"code":"RATE_LIMIT_EXCEEDED","type":"error"},"request_id":"chatcmpl-279a1f6c02014c95bfdb02edeff01bbd"}
# Request 18 failed: {"error":{"message":"You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.","param":null,"code":"RATE_LIMIT_EXCEEDED","type":"error"},"request_id":"chatcmpl-f0c70b0060544d48b94f5699daa4df6c"}
# Request 7 failed: {"error":{"message":"You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.","param":null,"code":"RATE_LIMIT_EXCEEDED","type":"error"},"request_id":"chatcmpl-6667ba36c3d14b08a970af6843d0fd84"}
# Request 5 failed: {"error":{"message":"You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.","param":null,"code":"RATE_LIMIT_EXCEEDED","type":"error"},"request_id":"chatcmpl-c0a83e22992249fdb58b09f0c00c93a6"}
# Request 4 failed: {"error":{"message":"You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.","param":null,"code":"RATE_LIMIT_EXCEEDED","type":"error"},"request_id":"chatcmpl-d3ca5032958f4413bb19814b0e641bfd"}
# Request 12 failed: {"error":{"message":"You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.","param":null,"code":"RATE_LIMIT_EXCEEDED","type":"error"},"request_id":"chatcmpl-b151d2f03c974bc29d9549fcce2e2c90"}
# Request 21 failed: {"error":{"message":"You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.","param":null,"code":"RATE_LIMIT_EXCEEDED","type":"error"},"request_id":"chatcmpl-617d8776682d460f9a36e48d54121b58"}
# Response 16: **Answer (tongue‑twister style):**
#
# > How much wood would a ...
# Response 17: A classic tongue‑tripper!  In reality a “woodchuck” (aka a g...
# Response 9: A classic tongue‑twister answer (and the one most people quo...
# Response 11: **Answer**
#
# A classic:
#
# > “A wood‑chuck would chuck wood a...
# Response 20: A classic tongue‑twister joke, not a hard science fact, but ...
# Response 23: A classic tongue‑twister and folklore riddle, the answer is ...
# Response 24: **Answer (Request 24)**
# According to a tongue‑twister spru...
# Response 10: **Answer to Request #10**
#
# A woodchuck would chuck *as much ...
# Response 1: **Answer**
#
# The classic answer to that tongue‑twister is:
#
# >...
# Response 13: **Answer to “How much wood could a wood‑chuck chuck if a woo...
# Response 2: # The Curious Wood Chuck
#
# ## Formatting
# - All content is...
